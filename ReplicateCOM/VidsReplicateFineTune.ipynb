# %%
import replicate

# %%
output = replicate.run(
    "wavespeedai/wan-2.1-t2v-480p",
    input={
        "prompt": "A large dragon walking on the streets of downtown Chicago at night",
        "fast_mode": "Balanced",
        "lora_scale": 1,
        "num_frames": 81,
        "aspect_ratio": "16:9",
        "sample_shift": 5,
        "sample_steps": 30,
        "frames_per_second": 16,
        "sample_guide_scale": 5
    }
)
print(output)
# Out:
# https://replicate.delivery/xezq/qCaIzKQEtWJ9HZ8sb1i1fbW73Ov9esBLziLGXJRnhUefB6NSB/output.mp4

# %% [markdown]
# ## Call my Fine Tuned model from Replicate

# %%
import replicate
from PIL import Image
from urllib.request import urlretrieve

# %%
output = replicate.run(
    "rcalix1/inclass_april2025:733429ab6a8dbc6dff5be04ad5aa39bd60dbed13e8aa91bf6c0751a97d93e8fb",
    input={"prompt": "rcalix as Indiana Jones in the Temple of Doom"}
)



res = output[0].url

# %%
urlretrieve(res, "April_out4.png")
# Out:
# ('April_out4.png', <http.client.HTTPMessage at 0x1f07fb10a00>)

# %%
background = Image.open("April_out4.png")
background
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1024x1024>
